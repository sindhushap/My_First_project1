# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("DATA SCIENCE SET 2.xlsx",sheetname="Sheet1",parse_dates = [5])

# %%
data.head()
# Out:
#       User id              Category         Product  Category_id  Product_id  \
# 0  9000000001        Medical Stores       Medicines           11           2
# 1  9000000001           Electronics          Mobile            9           4
# 2  9000000001             Hospitals  Health Checkup           12           6
# 3  9000000001  Movies/Entertainment   Movie Booking            8           7
# 4  9000000001           Hospitality          Dinner            8           9
#
#   Ordered Date      Time  bill value  Age  Income Gender   Profession  \
# 0   2017-05-02  14:00:00        1500   24   15000   Male  Call Centre
# 1   2017-11-02  14:00:00        4000   24   15000   Male  Call Centre
# 2   2017-08-10  14:00:00        5000   24   15000   Male  Call Centre
# 3   2017-02-02  10:00:00       12000   24   15000   Male  Call Centre
# 4   2018-01-02  14:00:00        8000   24   15000   Male  Call Centre
#
#    Home_Lattitude  Home_Longitude  Office_Lattitude  Office_Longitude  \
# ...

# %%
data.isnull().sum()
# Out:
# User id             0
# Category            0
# Product             0
# Category_id         0
# Product_id          0
# Ordered Date        0
# Time                0
# bill value          0
# Age                 0
# Income              0
# Gender              0
# Profession          0
# Home_Lattitude      0
# Home_Longitude      0
# Office_Lattitude    0
# Office_Longitude    0
# Family members      0
# Languages Known     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 18 columns):
# User id             239 non-null int64
# Category            239 non-null object
# Product             239 non-null object
# Category_id         239 non-null int64
# Product_id          239 non-null int64
# Ordered Date        239 non-null datetime64[ns]
# Time                239 non-null object
# bill value          239 non-null int64
# Age                 239 non-null int64
# Income              239 non-null int64
# Gender              239 non-null object
# Profession          239 non-null object
# Home_Lattitude      239 non-null float64
# Home_Longitude      239 non-null float64
# Office_Lattitude    239 non-null float64
# Office_Longitude    239 non-null float64
# Family members      239 non-null int64
# Languages Known     239 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(7), object(6)
# memory usage: 33.7+ KB

# %%
data.describe()
# Out:
#             User id  Category_id  Product_id    bill value         Age  \
# count  2.390000e+02   239.000000  239.000000    239.000000  239.000000
# mean   9.000000e+09    13.351464    7.426778   5944.769874   29.004184
# std    5.757484e+00     4.779366    4.499518   4941.596280    5.697927
# min    9.000000e+09     7.000000    1.000000    400.000000   22.000000
# 25%    9.000000e+09     9.000000    3.000000   1950.000000   24.000000
# 50%    9.000000e+09    12.000000    7.000000   5000.000000   28.000000
# 75%    9.000000e+09    17.000000   12.000000   9000.000000   32.000000
# max    9.000000e+09    22.000000   14.000000  23000.000000   40.000000
#
#              Income  Home_Lattitude  Home_Longitude  Office_Lattitude  \
# count    239.000000      239.000000      239.000000        239.000000
# mean   21861.924686       17.431024       78.444920         17.444009
# std     8264.646666        0.060677        0.067677          0.023262
# ...

# %%
data.shape
# Out:
# (239, 18)

# %%
data=data.rename(columns={"User id":"User_id","Ordered Date":"Ordered_Date","bill value":"Bill_Amount","Family members":"Family_Members","Languages Known":"Languages_Known"})

# %%
data.head()
# Out:
#       User_id              Category         Product  Category_id  Product_id  \
# 0  9000000001        Medical Stores       Medicines           11           2
# 1  9000000001           Electronics          Mobile            9           4
# 2  9000000001             Hospitals  Health Checkup           12           6
# 3  9000000001  Movies/Entertainment   Movie Booking            8           7
# 4  9000000001           Hospitality          Dinner            8           9
#
#   Ordered_Date      Time  Bill_Amount  Age  Income Gender   Profession  \
# 0   2017-05-02  14:00:00         1500   24   15000   Male  Call Centre
# 1   2017-11-02  14:00:00         4000   24   15000   Male  Call Centre
# 2   2017-08-10  14:00:00         5000   24   15000   Male  Call Centre
# 3   2017-02-02  10:00:00        12000   24   15000   Male  Call Centre
# 4   2018-01-02  14:00:00         8000   24   15000   Male  Call Centre
#
#    Home_Lattitude  Home_Longitude  Office_Lattitude  Office_Longitude  \
# ...

# %%
type(data.Ordered_Date[0])
# Out:
# pandas._libs.tslib.Timestamp

# %%
type(data.Time[0])
# Out:
# datetime.time

# %%
print(np.unique(data.Category))
# Out:
# [' Medical Stores' 'Apparels' 'Education' 'Electronics' 'Groceries'
#  'Holidays/Recreation' 'Hospitality' 'Hospitals' 'Jewellery'
#  'Movies/Entertainment' 'Transit']

# %%
data.Category.value_counts()
# Out:
# Transit                 22
# Holidays/Recreation     22
# Electronics             22
# Groceries               22
#  Medical Stores         22
# Education               22
# Hospitals               22
# Movies/Entertainment    22
# Apparels                21
# Hospitality             21
# Jewellery               21
# Name: Category, dtype: int64

# %%
print(np.unique(data.Product))
# Out:
# ['Cab Booking' 'Clothing' 'College Fee' 'Dinner' 'Gold Chain'
#  'Health Checkup' 'Medicines' 'Mobile' 'Movie Booking' 'Refridgerator'
#  'Resorts' 'Rice' 'School Fee' 'TV' 'Washing Machine']

# %%
data.Product.value_counts()
# Out:
# Resorts            22
# Movie Booking      22
# Rice               22
# Health Checkup     22
# Medicines          22
# Cab Booking        22
# Clothing           21
# Dinner             21
# Gold Chain         21
# School Fee         15
# TV                 15
# College Fee         7
# Mobile              5
# Refridgerator       1
# Washing Machine     1
# Name: Product, dtype: int64

# %%
#seggrigating by users
Users_data=data.groupby("User_id")
p=(group.sort_index(by="Category", ascending=True) for Product,group in Users_data)

# %%
for i in p:
    print(i)
# Out:
# C:\Users\merus\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   This is separate from the ipykernel package so we can avoid doing imports until
#        User_id              Category         Product  Category_id  Product_id  \
# 0   9000000001        Medical Stores       Medicines           11           2
# 10  9000000001        Medical Stores       Medicines           15          12
# 5   9000000001              Apparels        Clothing            7           1
# 1   9000000001           Electronics          Mobile            9           4
# 11  9000000001           Electronics              TV           10          11
# 6   9000000001             Groceries            Rice           20          13
# 7   9000000001   Holidays/Recreation         Resorts           16          10
# 4   9000000001           Hospitality          Dinner            8           9
# ...

# %%
data.Gender.value_counts()
# Out:
# Male      180
# Female     59
# Name: Gender, dtype: int64

# %%
gender=pd.get_dummies(data.Gender,prefix="Gender",drop_first="TRUE")
gender.head()
# Out:
#    Gender_Male
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
data.Profession.value_counts()
# Out:
# Doctor         36
# Banking        36
# Call Centre    36
# Marketing      36
# Business       36
# Lawyer         35
# Engineer       24
# Name: Profession, dtype: int64

# %%
profession=pd.get_dummies(data.Profession,prefix="Profession",drop_first="TRUE")
profession.head()
# Out:
#    Profession_Business  Profession_Call Centre  Profession_Doctor   \
# 0                    0                       1                   0
# 1                    0                       1                   0
# 2                    0                       1                   0
# 3                    0                       1                   0
# 4                    0                       1                   0
#
#    Profession_Engineer  Profession_Lawyer  Profession_Marketing
# 0                    0                  0                     0
# 1                    0                  0                     0
# 2                    0                  0                     0
# 3                    0                  0                     0
# 4                    0                  0                     0

# %%
data=pd.concat([data,gender,profession],axis=1)

# %%
data.head()
# Out:
#       User_id              Category         Product  Category_id  Product_id  \
# 0  9000000001        Medical Stores       Medicines           11           2
# 1  9000000001           Electronics          Mobile            9           4
# 2  9000000001             Hospitals  Health Checkup           12           6
# 3  9000000001  Movies/Entertainment   Movie Booking            8           7
# 4  9000000001           Hospitality          Dinner            8           9
#
#   Ordered_Date      Time  Bill_Amount  Age  Income          ...           \
# 0   2017-05-02  14:00:00         1500   24   15000          ...
# 1   2017-11-02  14:00:00         4000   24   15000          ...
# 2   2017-08-10  14:00:00         5000   24   15000          ...
# 3   2017-02-02  10:00:00        12000   24   15000          ...
# 4   2018-01-02  14:00:00         8000   24   15000          ...
#
#   Office_Longitude Family_Members           Languages_Known  Gender_Male  \
# ...

# %%
data.User_id.value_counts().sort_index()
# Out:
# 9000000001    12
# 9000000002    12
# 9000000003    12
# 9000000004    12
# 9000000005    12
# 9000000006    12
# 9000000007    12
# 9000000008    12
# 9000000009    12
# 9000000010    12
# 9000000011    12
# 9000000012    12
# 9000000013    12
# 9000000014    12
# 9000000015    12
# 9000000016    12
# 9000000017    12
# 9000000018    12
# 9000000019    12
# 9000000020    11
# Name: User_id, dtype: int64

# %%
#needs Vs Luxury(Income Vs Expenditure)
#Each users maximum expenditure on each category
data.groupby(["User_id","Income","Category"])["Bill_Amount"].max()
# Out:
# User_id     Income  Category
# 9000000001  15000    Medical Stores          1500
#                     Apparels                 1900
#                     Electronics              4000
#                     Groceries                3000
#                     Holidays/Recreation      2500
#                     Hospitality              8000
#                     Hospitals                5000
#                     Jewellery                9000
#                     Movies/Entertainment    12000
#                     Transit                  2000
# 9000000002  25000    Medical Stores          2000
#                     Apparels                 8000
#                     Education                4000
#                     Groceries                4600
#                     Holidays/Recreation      4600
#                     Hospitality             16000
#                     Hospitals               15000
#                     Jewellery                3000
# ...

# %%
data["Ordered_Date_WeekDay_name"]=data.Ordered_Date.dt.weekday_name
data["Ordered_Date_WeekDay"]=data.Ordered_Date.dt.weekday
data["Ordered_Date_Month"]=data.Ordered_Date.dt.month
data.head()
# Out:
#       User_id              Category         Product  Category_id  Product_id  \
# 0  9000000001        Medical Stores       Medicines           11           2
# 1  9000000001           Electronics          Mobile            9           4
# 2  9000000001             Hospitals  Health Checkup           12           6
# 3  9000000001  Movies/Entertainment   Movie Booking            8           7
# 4  9000000001           Hospitality          Dinner            8           9
#
#   Ordered_Date      Time  Bill_Amount  Age  Income         ...          \
# 0   2017-05-02  14:00:00         1500   24   15000         ...
# 1   2017-11-02  14:00:00         4000   24   15000         ...
# 2   2017-08-10  14:00:00         5000   24   15000         ...
# 3   2017-02-02  10:00:00        12000   24   15000         ...
# 4   2018-01-02  14:00:00         8000   24   15000         ...
#
#   Gender_Male Profession_Business  Profession_Call Centre  Profession_Doctor   \
# ...

# %%
data.groupby(["User_id","Ordered_Date_Month","Income","Category",])["Bill_Amount"].max()
# Out:
# User_id     Ordered_Date_Month  Income  Category
# 9000000001  1                   15000   Hospitality              8000
#             2                   15000   Holidays/Recreation      2500
#                                         Movies/Entertainment    12000
#             3                   15000   Groceries                3000
#             5                   15000    Medical Stores          1500
#             6                   15000   Apparels                 1900
#             8                   15000   Hospitals                5000
#                                         Jewellery                9000
#             10                  15000   Transit                  2000
#             11                  15000   Electronics              4000
#             12                  15000   Electronics               900
# 9000000002  1                   25000   Holidays/Recreation      4600
#             2                   25000   Transit                 16000
# ...

# %%
data.groupby("Income")["Bill_Amount"].mean().plot()

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(data.Income)
plt.title('Income Distribution')

plt.subplot(1, 2, 2)
plt.scatter(data.Income, data.Age, s = 20, color="r",alpha = 0.75)
plt.xlabel('Income')
plt.ylabel('Bill_Amount')

plt.tight_layout()

# %%
"""category=[]
plt.figure(figsize=(10, 10))
for i in data["Category_id"]:
    if i not in category:
        category.append(i)
        plt.subplot(1,1,10)
        plt.scatter(data["Category_id"], data["Income"], s = 20, color="r",alpha = 0.75)
        plt.xlabel('Income')
        plt.ylabel('Bill_Amount')
        
plt.tight_layout()"""
;
# Out:
# ''

# %%
from sklearn.cluster import KMeans

# %%
X=data.iloc[:,[0,3,4,7,8,9]].values

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init="k-means++",max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title("Elbow Curve")
plt.xlabel("Number of clusters")
plt.ylabel("wcss")
plt.show()

# %%
kmeans=KMeans(n_clusters=3,init="k-means++",max_iter=300,n_init=10,random_state=0)
y_means=kmeans.fit_predict(X)

# %%
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
print(centroids)
# Out:
# [[  9.00000001e+09   1.26538462e+01   7.21153846e+00   1.36846154e+04
#     3.38461538e+01   2.90769231e+04]
#  [  9.00000001e+09   1.34716981e+01   7.43396226e+00   3.69905660e+03
#     2.44150943e+01   1.36320755e+04]
#  [  9.00000001e+09   1.36419753e+01   7.55555556e+00   3.91481481e+03
#     3.19012346e+01   2.80000000e+04]]

# %%
import seaborn as sns

# %%
sns.clustermap(centroids)
plt.show()

# %%
color_theme = np.array(['purple','lightsalmon','lightgreen','lightblue'])
marker_style=np.array(['^','*','^','*'])

# %%
plt.figure(figsize = (10,10))
plt.scatter(x=data.Income,y=data.Bill_Amount,color=color_theme[labels],marker='^',s=50)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.scatter(x=data.Category_id,y=data.Bill_Amount,color=color_theme[labels],marker="^",s=50)
plt.legend()
plt.show()

# %%
#data.drop(data.columns[[1,2,10,11,17]],axis=1,inplace=True)
#data.head()

# %%
data.Family_Members=data.Family_Members.astype("category")

# %%
type(data.Family_Members[0])
# Out:
# numpy.int64

# %%
#Date N time
print("min=",data.Ordered_Date.min())
print("max=",data.Ordered_Date.max())
# Out:
# min= 2017-01-20 00:00:00
# max= 2018-07-01 00:00:00

# %%
data.Ordered_Date.dt.weekday.value_counts().sort_index()
# Out:
# 0    30
# 1    33
# 2    33
# 3    38
# 4    37
# 5    34
# 6    34
# Name: Ordered_Date, dtype: int64

# %%
# %matplotlib inline
data.Ordered_Date.dt.weekday.value_counts().sort_index().plot(kind="bar")

# %%
data.Ordered_Date.dt.month.value_counts().sort_index()
# Out:
# 1     21
# 2     14
# 3     24
# 4     14
# 5     24
# 6     25
# 7     12
# 8     25
# 9     17
# 10    20
# 11    21
# 12    22
# Name: Ordered_Date, dtype: int64

# %%
# %matplotlib inline
data.Ordered_Date.dt.month.value_counts().sort_index().plot(kind="bar")

# %%
data_by_year=data.Ordered_Date.dt.year
data_by_year.head()
# Out:
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2018
# Name: Ordered_Date, dtype: int64

# %%
data.groupby(["Ordered_Date"])["Bill_Amount"].mean().plot(kind="bar")

# %%
data.groupby(["Ordered_Date_Month"])["Bill_Amount"].mean().plot(kind="line")

# %%
data.groupby(["Ordered_Date_WeekDay_name"])["Bill_Amount"].mean().plot(kind="bar")

# %%
data.groupby(["Ordered_Date_WeekDay"])["Bill_Amount"].mean().sort_index().plot(kind="bar")

# %%
from sklearn.linear_model import LogisticRegression

# %%
data.columns

# %%
mylist=["Ordered_Date","Time","Ordered_Date_WeekDay_name",'Ordered_Date_WeekDay',
 'Ordered_Date_Month']
mylist

# %%
cols=[col for col in data.columns if col not in mylist]
cols

# %%
X = data[cols].values
X

# %%
#X=data.loc[:,data.columns!=["Ordered_Date","Time","Home_Address","Office_Address"]].values

# %%
X[2,:]

# %%
# clustering 
from sklearn.cluster import KMeans

# %%
#X=data.iloc[:,[0,1,2,5,6,7]].values

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init="k-means++",max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title("Elbow Curve")
plt.xlabel("Number of clusters")
plt.ylabel("wcss")
plt.show()

# %%
kmeans=KMeans(n_clusters=3,init="k-means++",max_iter=300,n_init=10,random_state=0)
y_means=kmeans.fit_predict(X)

# %%
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
print(centroids)

# %%
#Analysis of timestamp
#n.of transaction done by each individual on a day
