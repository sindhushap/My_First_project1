# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_excel("DATA_SCIENCE_SET_25_26.xlsx",sheetname="Sheet1",parse_dates = [3],na_values="0")
# Out:
# C:\Users\Tester\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
#Renaming columns
data=data.rename(columns={"User id":"User_id","Order Date":"Ordered_Date","Order Time":"Ordered_Time","bill value":"Bill_Amount","Home Address":"Home_Address","Office Address":"Office_Address","Family members":"Family_Members","Languages Known":"Languages_Known"})

# %%
data.head()
# Out:
#       User_id  Category  Product         Ordered_Date Ordered_Time  \
# 0  9123456794        11      4.0  2018-01-01 00:00:00     21:30:00
# 1  9999999978         6      NaN  2018-01-04 00:00:00     22:55:00
# 2  9123456782         8      8.0  2018-01-10 00:00:00     14:12:00
# 3  9999999975        13      NaN  2018-01-12 00:00:00     10:10:00
# 4  9123456790         9      1.0  2018-01-21 00:00:00     13:40:00
#
#    Bill_Amount  Age  Income  Gender       Profession  Home_Latitude  \
# 0         2000   26   45000  Female           Doctor      17.488666
# 1         2650   30   22000  Female     Entreprenuer      17.400205
# 2        25000   24   50000  Female         Engineer      17.518252
# 3          750   24   23000  Female  IT Professional      17.424879
# 4         8700   28   60000  Female         Business      17.443972
#
#    Home_Longitude      Unnamed: 12  Office_Latitude  Office_Longitude  \
# 0       78.389712     17z(J.N.T.U)        17.474387         78.297519
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 18 columns):
# User_id             220 non-null int64
# Category            220 non-null int64
# Product             63 non-null float64
# Ordered_Date        220 non-null object
# Ordered_Time        220 non-null object
# Bill_Amount         220 non-null int64
# Age                 220 non-null int64
# Income              220 non-null int64
# Gender              220 non-null object
# Profession          220 non-null object
# Home_Latitude       220 non-null float64
# Home_Longitude      220 non-null float64
# Unnamed: 12         81 non-null object
# Office_Latitude     177 non-null float64
# Office_Longitude    177 non-null float64
# Unnamed: 15         81 non-null object
# Family_Members      220 non-null int64
# Languages_Known     220 non-null object
# dtypes: float64(5), int64(6), object(7)
# memory usage: 31.0+ KB

# %%
data.describe()
# Out:
#             User_id    Category    Product   Bill_Amount         Age  \
# count  2.200000e+02  220.000000  63.000000    220.000000  220.000000
# mean   9.672727e+09    6.881818   4.857143   3270.518182   30.150000
# std    4.256123e+08    4.263537   2.787398   6055.698128   11.645849
# min    9.000000e+09    1.000000   1.000000     15.000000   13.000000
# 25%    9.123457e+09    2.000000   2.000000    546.750000   23.000000
# 50%    1.000000e+10    6.000000   5.000000   1500.000000   26.000000
# 75%    1.000000e+10   11.000000   7.000000   3000.000000   32.000000
# max    1.000000e+10   14.000000  11.000000  50000.000000   62.000000
#
#               Income  Home_Latitude  Home_Longitude  Office_Latitude  \
# count     220.000000     220.000000      220.000000       177.000000
# mean    30359.090909      17.447873       78.429565        17.448620
# std     19188.637217       0.045752        0.062871         0.047535
# ...

# %%
data.isnull().sum()
# Out:
# User_id               0
# Category              0
# Product             157
# Ordered_Date          0
# Ordered_Time          0
# Bill_Amount           0
# Age                   0
# Income                0
# Gender                0
# Profession            0
# Home_Latitude         0
# Home_Longitude        0
# Unnamed: 12         139
# Office_Latitude      43
# Office_Longitude     43
# Unnamed: 15         139
# Family_Members        0
# Languages_Known       0
# dtype: int64

# %%
data.Income.loc[data.Income==0]=np.round(data.Income.mean(),2)
data.iloc[[31,32,48,50,51,53]]
# Out:
# C:\Users\Tester\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#        User_id  Category  Product         Ordered_Date Ordered_Time  \
# 31  9999999986        13      NaN  2018-02-27 00:00:00     18:03:00
# 32  9999999986        13      NaN  2018-02-28 00:00:00     19:10:00
# 48  9999999987        14      NaN  2018-03-27 00:00:00     12:45:00
# 50  9999999987         1      NaN  2018-03-28 00:00:00     21:13:00
# 51  9999999987         1      NaN  2018-03-29 00:00:00     18:03:00
# 53  9999999987        10      NaN  2018-03-31 00:00:00     08:50:00
#
#     Bill_Amount  Age    Income  Gender Profession  Home_Latitude  \
# 31          500   13  30359.09    Male    Student      17.496305
# ...

# %%
data.groupby(["Category"])["Bill_Amount"].count()
# Out:
# Category
# 1     38
# 2     20
# 3     13
# 5     12
# 6     28
# 7      7
# 8      3
# 9     11
# 10    28
# 11    29
# 12     9
# 13    18
# 14     4
# Name: Bill_Amount, dtype: int64

# %%
data.Category.value_counts().sort_index().plot()

# %%
# %matplotlib inline
data.groupby(["Category"])["Bill_Amount"].mean().plot()

# %%
data.set_index("Category").T.head()
# Out:
# Category                       11                   6                    8   \
# User_id                9123456794           9999999978           9123456782
# Product                         4                  NaN                    8
# Ordered_Date  2018-01-01 00:00:00  2018-01-04 00:00:00  2018-01-10 00:00:00
# Ordered_Time             21:30:00             22:55:00             14:12:00
# Bill_Amount                  2000                 2650                25000
#
# Category                       13                   9                    9   \
# User_id                9999999975           9123456790           9123456789
# Product                       NaN                    1                    8
# Ordered_Date  2018-01-12 00:00:00  2018-01-21 00:00:00  2018-01-21 00:00:00
# Ordered_Time             10:10:00             13:40:00             15:30:00
# Bill_Amount                   750                 8700                 1500
#
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
data_2=data.loc[:,["User_id","Category","Bill_Amount","Income"]]
print(data_2.head())
#data_2=data_2.set_index("Category").T
# Out:
#       User_id  Category  Bill_Amount   Income
# 0  9123456794        11         2000  45000.0
# 1  9999999978         6         2650  22000.0
# 2  9123456782         8        25000  50000.0
# 3  9999999975        13          750  23000.0
# 4  9123456790         9         8700  60000.0

# %% [markdown]
# ### Needs vs Luxury

# %%
data_2.Income.value_counts().sort_index()
# Out:
# 6000.00       6
# 15000.00      1
# 16000.00      6
# 20000.00      6
# 22000.00     12
# 23000.00     14
# 25000.00     15
# 28000.00      2
# 30000.00     46
# 30359.09     31
# 35000.00      3
# 37000.00      8
# 38000.00      2
# 40000.00      1
# 42000.00      4
# 45000.00     30
# 50000.00     20
# 60000.00      5
# 75000.00      3
# 85000.00      3
# 100000.00     2
# Name: Income, dtype: int64

# %%
data_2["Income_cat"]=data.Income
print(data_2.head())
#data_2.Income_cat.loc[data_2.Income<=50000]=0
#data_2.Income_cat.loc[data_2.Income>50000]=1
#data_2.Income_cat=data_2.Income_cat.astype(int)
#data_2.head()
# Out:
#       User_id  Category  Bill_Amount   Income  Income_cat
# 0  9123456794        11         2000  45000.0     45000.0
# 1  9999999978         6         2650  22000.0     22000.0
# 2  9123456782         8        25000  50000.0     50000.0
# 3  9999999975        13          750  23000.0     23000.0
# 4  9123456790         9         8700  60000.0     60000.0

# %%
for i in range(0,len(data_2)):
    if data_2.Income.iloc[i] <= 25000:
        data_2.Income_cat.iloc[i]="Lower"
    elif data_2.Income.iloc[i] <= 45000:
        data_2.Income_cat.iloc[i]="Lower_Middle"
    elif data_2.Income.iloc[i] <= 65000:
        data_2.Income_cat.iloc[i]="Upper_Middle"
    elif data_2.Income.iloc[i] > 65000:
        data_2.Income_cat.iloc[i]="High"
# Out:
# C:\Users\Tester\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data_2.head()
# Out:
#       User_id  Category  Bill_Amount   Income    Income_cat
# 0  9123456794        11         2000  45000.0  Lower_Middle
# 1  9999999978         6         2650  22000.0         Lower
# 2  9123456782         8        25000  50000.0  Upper_Middle
# 3  9999999975        13          750  23000.0         Lower
# 4  9123456790         9         8700  60000.0  Upper_Middle

# %%
data_2.Income_cat.iloc[33]
# Out:
# 'High'

# %%
f, ax = plt.subplots(figsize=(10,10
                             ))
sns.swarmplot(x=data_2.Category, y=data_2.Bill_Amount,data=data_2,hue=data_2.Income_cat,size=10)

# %%
sns.boxplot(x=data_2.Category, y=data_2.Bill_Amount,data=data_2,hue=data_2.Income_cat,saturation=0.75, width=0.8, dodge=True, fliersize=5 );

# %%
# Draw a nested boxplot 
f, ax = plt.subplots(figsize=(12, 13))
sns.boxplot(x=data_2.Category, y=data_2.Bill_Amount,data=data_2,hue=data_2.Income_cat, palette="PRGn",orient="v")
sns.despine(offset=10, trim=True)

# %%
f, ax = plt.subplots(figsize=(10,5))
sns.barplot(x=data_2.Category, y=data_2.Bill_Amount,data=data_2,hue=data_2.Income_cat)

# %%
unique_user=data_2.User_id.unique()

# %%
unique_user
# Out:
# array([9123456794, 9999999978, 9123456782, 9999999975, 9123456790,
#        9123456789, 9123456798, 9123456799, 9123456781, 9123456793,
#        9999999981, 9123456787, 9123456785, 9123456780, 9123456792,
#        9999999980, 9123456783, 9123456796, 9123456791, 9999999986,
#        9123456786, 9999999985, 9999999988, 9999999973, 9999999991,
#        9999999987, 9123456788, 9999999983, 9999999982, 9123456797,
#        9999999984, 9123456784, 9000000006, 9999999976, 9999999979,
#        9999999972, 9999999971, 9999999974, 9123456795, 9999999990,
#        9999999989, 9999999977], dtype=int64)

# %%
len(unique_user)
# Out:
# 42

# %%
Users_data=data_2.groupby(["Category"])

# %%
for Category,group in Users_data:
    print(Category)
    print(group)
# Out:
# 1
#         User_id  Category  Bill_Amount    Income    Income_cat
# 16   9123456782         1          400  50000.00  Upper_Middle
# 26   9999999975         1         1600  23000.00         Lower
# 35   9999999980         1          980  25000.00         Lower
# 45   9999999980         1          530  25000.00         Lower
# 50   9999999987         1         1500  30359.09  Lower_Middle
# 51   9999999987         1         1500  30359.09  Lower_Middle
# 59   9123456782         1          550  50000.00  Upper_Middle
# 68   9999999982         1          888  30000.00  Lower_Middle
# 72   9999999986         1           60  30359.09  Lower_Middle
# 75   9999999978         1         3200  22000.00         Lower
# 92   9999999982         1          100  30000.00  Lower_Middle
# 100  9999999972         1          120  30000.00  Lower_Middle
# 103  9999999982         1          156  30000.00  Lower_Middle
# 109  9999999991         1         2300  42000.00  Lower_Middle
# ...

# %%
Users_data.get_group(1)
# Out:
#         User_id  Category  Bill_Amount    Income    Income_cat
# 16   9123456782         1          400  50000.00  Upper_Middle
# 26   9999999975         1         1600  23000.00         Lower
# 35   9999999980         1          980  25000.00         Lower
# 45   9999999980         1          530  25000.00         Lower
# 50   9999999987         1         1500  30359.09  Lower_Middle
# 51   9999999987         1         1500  30359.09  Lower_Middle
# 59   9123456782         1          550  50000.00  Upper_Middle
# 68   9999999982         1          888  30000.00  Lower_Middle
# 72   9999999986         1           60  30359.09  Lower_Middle
# 75   9999999978         1         3200  22000.00         Lower
# 92   9999999982         1          100  30000.00  Lower_Middle
# 100  9999999972         1          120  30000.00  Lower_Middle
# 103  9999999982         1          156  30000.00  Lower_Middle
# 109  9999999991         1         2300  42000.00  Lower_Middle
# ...

# %%
Users1_data=data_2.groupby(["User_id"])

# %%
for User_id,grp in Users1_data:
    print(User_id)
    print(grp)
# Out:
# 9000000006
#        User_id  Category  Bill_Amount   Income    Income_cat
# 86  9000000006        11        10000  35000.0  Lower_Middle
# 9123456780
#         User_id  Category  Bill_Amount   Income    Income_cat
# 17   9123456780        11        10000  30000.0  Lower_Middle
# 36   9123456780         8         6500  30000.0  Lower_Middle
# 40   9123456780        10         3000  30000.0  Lower_Middle
# 117  9123456780         9         1800  30000.0  Lower_Middle
# 118  9123456780        11         2500  30000.0  Lower_Middle
# 122  9123456780        10         3000  30000.0  Lower_Middle
# 124  9123456780         9         2500  30000.0  Lower_Middle
# 128  9123456780        11         4000  30000.0  Lower_Middle
# 155  9123456780        11         7000  30000.0  Lower_Middle
# 9123456781
#         User_id  Category  Bill_Amount   Income    Income_cat
# 10   9123456781        10        25000  30000.0  Lower_Middle
# 129  9123456781        11         2500  30000.0  Lower_Middle
# ...

# %%
print(Users1_data.keys)
print(Users1_data.groups.keys())
# Out:
# ['User_id']
# dict_keys([9000000006, 9123456780, 9123456781, 9123456782, 9123456783, 9123456784, 9123456785, 9123456786, 9123456787, 9123456788, 9123456789, 9123456790, 9123456791, 9123456792, 9123456793, 9123456794, 9123456795, 9123456796, 9123456797, 9123456798, 9123456799, 9999999971, 9999999972, 9999999973, 9999999974, 9999999975, 9999999976, 9999999977, 9999999978, 9999999979, 9999999980, 9999999981, 9999999982, 9999999983, 9999999984, 9999999985, 9999999986, 9999999987, 9999999988, 9999999989, 9999999990, 9999999991])

# %%
list_1=list(Users1_data.groups.keys())
new_df=Users1_data.mean()
new_df.head()
new_df.columns
# Out:
# Index(['Category', 'Bill_Amount', 'Income'], dtype='object')

# %%
Users2_data=data_2.groupby(["User_id","Category"])
type(Users2_data)
print(Users2_data.keys)
# Out:
# ['User_id', 'Category']

# %%
for User_id,grp in Users2_data:
    print(User_id)
    print(grp)
# Out:
# (9000000006, 11)
#        User_id  Category  Bill_Amount   Income    Income_cat
# 86  9000000006        11        10000  35000.0  Lower_Middle
# (9123456780, 8)
#        User_id  Category  Bill_Amount   Income    Income_cat
# 36  9123456780         8         6500  30000.0  Lower_Middle
# (9123456780, 9)
#         User_id  Category  Bill_Amount   Income    Income_cat
# 117  9123456780         9         1800  30000.0  Lower_Middle
# 124  9123456780         9         2500  30000.0  Lower_Middle
# (9123456780, 10)
#         User_id  Category  Bill_Amount   Income    Income_cat
# 40   9123456780        10         3000  30000.0  Lower_Middle
# 122  9123456780        10         3000  30000.0  Lower_Middle
# (9123456780, 11)
#         User_id  Category  Bill_Amount   Income    Income_cat
# 17   9123456780        11        10000  30000.0  Lower_Middle
# 118  9123456780        11         2500  30000.0  Lower_Middle
# 128  9123456780        11         4000  30000.0  Lower_Middle
# ...

# %%
Users2_data.groups.keys()
# Out:
# dict_keys([(9000000006, 11), (9123456780, 8), (9123456780, 9), (9123456780, 10), (9123456780, 11), (9123456781, 10), (9123456781, 11), (9123456782, 1), (9123456782, 5), (9123456782, 6), (9123456782, 8), (9123456782, 10), (9123456782, 11), (9123456782, 12), (9123456783, 6), (9123456783, 7), (9123456783, 9), (9123456783, 10), (9123456783, 11), (9123456783, 12), (9123456783, 13), (9123456783, 14), (9123456784, 10), (9123456784, 11), (9123456785, 9), (9123456785, 10), (9123456785, 11), (9123456786, 9), (9123456786, 10), (9123456786, 11), (9123456787, 9), (9123456787, 10), (9123456787, 11), (9123456788, 11), (9123456789, 9), (9123456789, 10), (9123456789, 11), (9123456790, 9), (9123456790, 10), (9123456790, 11), (9123456791, 9), (9123456791, 10), (9123456791, 11), (9123456792, 10), (9123456792, 11), (9123456793, 10), (9123456793, 11), (9123456794, 10), (9123456794, 11), (9123456795, 10), (9123456795, 11), (9123456796, 10), (9123456796, 11), (9123456797, 10), (9123456797, 11), (9123456798,
# ...

# %%
p=Users2_data.mean()
print(type(p))
p.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                      Bill_Amount   Income
# User_id    Category
# 9000000006 11            10000.0  35000.0
# 9123456780 8              6500.0  30000.0
#            9              2150.0  30000.0
#            10             3000.0  30000.0
#            11             5875.0  30000.0

# %%
print(p.columns)
# Out:
# Index(['Bill_Amount', 'Income'], dtype='object')

# %%
print(Users2_data.keys)
Users2_data.keys[1]
#Users2_data.groups
# Out:
# ['User_id', 'Category']
# 'Category'

# %%
Users2_data.get_group((9000000006,11))
# Out:
#        User_id  Category  Bill_Amount   Income    Income_cat
# 86  9000000006        11        10000  35000.0  Lower_Middle

# %%
keys=list(Users2_data.groups.keys())
keys
# Out:
# [(9000000006, 11),
#  (9123456780, 8),
#  (9123456780, 9),
#  (9123456780, 10),
#  (9123456780, 11),
#  (9123456781, 10),
#  (9123456781, 11),
#  (9123456782, 1),
#  (9123456782, 5),
#  (9123456782, 6),
#  (9123456782, 8),
#  (9123456782, 10),
#  (9123456782, 11),
#  (9123456782, 12),
#  (9123456783, 6),
#  (9123456783, 7),
#  (9123456783, 9),
#  (9123456783, 10),
#  (9123456783, 11),
#  (9123456783, 12),
#  (9123456783, 13),
#  (9123456783, 14),
#  (9123456784, 10),
#  (9123456784, 11),
#  (9123456785, 9),
#  (9123456785, 10),
#  (9123456785, 11),
#  (9123456786, 9),
#  (9123456786, 10),
#  (9123456786, 11),
#  (9123456787, 9),
#  (9123456787, 10),
#  (9123456787, 11),
#  (9123456788, 11),
#  (9123456789, 9),
#  (9123456789, 10),
#  (9123456789, 11),
#  (9123456790, 9),
#  (9123456790, 10),
#  (9123456790, 11),
#  (9123456791, 9),
#  (9123456791, 10),
#  (9123456791, 11),
#  (9123456792, 10),
#  (9123456792, 11),
#  (9123456793, 10),
#  (9123456793, 11),
#  (9123456794, 10),
# ...

# %%
keys[0]
# Out:
# (9000000006, 11)

# %%
[x[1] for x in keys]
# Out:
# [11,
#  8,
#  9,
#  10,
#  11,
#  10,
#  11,
#  1,
#  5,
#  6,
#  8,
#  10,
#  11,
#  12,
#  6,
#  7,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  10,
#  11,
#  9,
#  10,
#  11,
#  9,
#  10,
#  11,
#  9,
#  10,
#  11,
#  11,
#  9,
#  10,
#  11,
#  9,
#  10,
#  11,
#  9,
#  10,
#  11,
#  10,
#  11,
#  10,
#  11,
#  10,
#  11,
#  10,
#  11,
#  10,
#  11,
#  10,
#  11,
#  10,
#  11,
#  10,
#  11,
#  7,
#  1,
#  2,
#  3,
#  10,
#  13,
#  1,
#  2,
#  3,
#  6,
#  7,
#  13,
#  1,
#  6,
#  13,
#  1,
#  2,
#  3,
#  6,
#  13,
#  1,
#  2,
#  3,
#  6,
#  7,
#  10,
#  12,
#  13,
#  2,
#  10,
#  13,
#  1,
#  3,
#  6,
#  9,
#  2,
#  3,
#  7,
#  12,
#  14,
#  1,
#  2,
#  3,
#  5,
#  6,
#  9,
#  10,
#  11,
#  13,
#  6,
#  1,
#  2,
#  1,
#  3,
#  5,
#  7,
#  1,
#  13,
#  1,
#  2,
#  6,
#  10,
#  11,
#  14,
#  5,
#  10,
#  11,
#  2,
#  1,
#  5]

# %%
p_df=pd.DataFrame()
for key in keys:
    p_df=p_df.append(Users2_data.get_group(key))

print(p_df)
# Out:
#         User_id  Category  Bill_Amount     Income    Income_cat
# 86   9000000006        11        10000   35000.00  Lower_Middle
# 36   9123456780         8         6500   30000.00  Lower_Middle
# 117  9123456780         9         1800   30000.00  Lower_Middle
# 124  9123456780         9         2500   30000.00  Lower_Middle
# 40   9123456780        10         3000   30000.00  Lower_Middle
# 122  9123456780        10         3000   30000.00  Lower_Middle
# 17   9123456780        11        10000   30000.00  Lower_Middle
# 118  9123456780        11         2500   30000.00  Lower_Middle
# 128  9123456780        11         4000   30000.00  Lower_Middle
# 155  9123456780        11         7000   30000.00  Lower_Middle
# 10   9123456781        10        25000   30000.00  Lower_Middle
# 129  9123456781        11         2500   30000.00  Lower_Middle
# 16   9123456782         1          400   50000.00  Upper_Middle
# 59   9123456782         1          550   50000.00  Upper_Middle
# ...

# %%
p_df.head()
# Out:
#         User_id  Category  Bill_Amount   Income    Income_cat
# 86   9000000006        11        10000  35000.0  Lower_Middle
# 36   9123456780         8         6500  30000.0  Lower_Middle
# 117  9123456780         9         1800  30000.0  Lower_Middle
# 124  9123456780         9         2500  30000.0  Lower_Middle
# 40   9123456780        10         3000  30000.0  Lower_Middle

# %%
p_df=data_2.groupby(["User_id","Category"]).mean().reset_index()
p_df
# Out:
#         User_id  Category   Bill_Amount     Income
# 0    9000000006        11  10000.000000   35000.00
# 1    9123456780         8   6500.000000   30000.00
# 2    9123456780         9   2150.000000   30000.00
# 3    9123456780        10   3000.000000   30000.00
# 4    9123456780        11   5875.000000   30000.00
# 5    9123456781        10  25000.000000   30000.00
# 6    9123456781        11   2500.000000   30000.00
# 7    9123456782         1    475.000000   50000.00
# 8    9123456782         5    600.000000   50000.00
# 9    9123456782         6   1800.000000   50000.00
# 10   9123456782         8  22500.000000   50000.00
# 11   9123456782        10   5000.000000   50000.00
# 12   9123456782        11   1500.000000   50000.00
# 13   9123456782        12  34000.000000   50000.00
# 14   9123456783         6   1800.000000   45000.00
# 15   9123456783         7  17300.000000   45000.00
# 16   9123456783         9   5500.000000   45000.00
# ...

# %%
p_df["Income_cat"]=""
print(p_df.head())
# Out:
#       User_id  Category  Bill_Amount   Income Income_cat
# 0  9000000006        11      10000.0  35000.0
# 1  9123456780         8       6500.0  30000.0
# 2  9123456780         9       2150.0  30000.0
# 3  9123456780        10       3000.0  30000.0
# 4  9123456780        11       5875.0  30000.0

# %%
for i in range(0,len(p_df)):
    if p_df.Income.iloc[i] <= 25000:
        p_df.Income_cat.iloc[i]="Lower"
    elif p_df.Income.iloc[i] <= 45000:
        p_df.Income_cat.iloc[i]="Lower_Middle"
    elif p_df.Income.iloc[i] <= 65000:
        p_df.Income_cat.iloc[i]="Upper_Middle"
    elif p_df.Income.iloc[i] > 65000:
        p_df.Income_cat.iloc[i]="High"
# Out:
# C:\Users\Tester\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
p_df.head()
# Out:
#       User_id  Category  Bill_Amount   Income    Income_cat
# 0  9000000006        11      10000.0  35000.0  Lower_Middle
# 1  9123456780         8       6500.0  30000.0  Lower_Middle
# 2  9123456780         9       2150.0  30000.0  Lower_Middle
# 3  9123456780        10       3000.0  30000.0  Lower_Middle
# 4  9123456780        11       5875.0  30000.0  Lower_Middle

# %%
len(p_df.User_id.unique())
# Out:
# 42

# %%
p_df[p_df.User_id==9123456782]
# Out:
#        User_id  Category  Bill_Amount   Income    Income_cat
# 7   9123456782         1        475.0  50000.0  Upper_Middle
# 8   9123456782         5        600.0  50000.0  Upper_Middle
# 9   9123456782         6       1800.0  50000.0  Upper_Middle
# 10  9123456782         8      22500.0  50000.0  Upper_Middle
# 11  9123456782        10       5000.0  50000.0  Upper_Middle
# 12  9123456782        11       1500.0  50000.0  Upper_Middle
# 13  9123456782        12      34000.0  50000.0  Upper_Middle

# %%
p_df[p_df.User_id==9999999973]
# Out:
#        User_id  Category  Bill_Amount   Income Income_cat
# 61  9999999973         2        150.0  20000.0      Lower
# 62  9999999973         3        800.0  20000.0      Lower
# 63  9999999973        10       1900.0  20000.0      Lower
# 64  9999999973        13        750.0  20000.0      Lower

# %%
p_df
# Out:
#         User_id  Category   Bill_Amount     Income    Income_cat
# 0    9000000006        11  10000.000000   35000.00  Lower_Middle
# 1    9123456780         8   6500.000000   30000.00  Lower_Middle
# 2    9123456780         9   2150.000000   30000.00  Lower_Middle
# 3    9123456780        10   3000.000000   30000.00  Lower_Middle
# 4    9123456780        11   5875.000000   30000.00  Lower_Middle
# 5    9123456781        10  25000.000000   30000.00  Lower_Middle
# 6    9123456781        11   2500.000000   30000.00  Lower_Middle
# 7    9123456782         1    475.000000   50000.00  Upper_Middle
# 8    9123456782         5    600.000000   50000.00  Upper_Middle
# 9    9123456782         6   1800.000000   50000.00  Upper_Middle
# 10   9123456782         8  22500.000000   50000.00  Upper_Middle
# 11   9123456782        10   5000.000000   50000.00  Upper_Middle
# 12   9123456782        11   1500.000000   50000.00  Upper_Middle
# ...

# %%
for user in p_df.User_id:
    df=p_df[p_df["User_id"]==user]
    label=df["Category"]
    values=df["Bill_Amount"]
    print(user)
    print(df.Income)
    # only "explode" the 2nd slice (i.e. 'Hogs')
    fig1, ax1 = plt.subplots()
    ax1.pie(values,labels=label, autopct='%1.1f%%',
        shadow=True, startangle=90)
    #plt.legend(title=df.Category,loc=3)
    # Equal aspect ratio ensures that pie is drawn as a circle
    ax1.axis('equal')  
    plt.tight_layout()
    plt.show()
# Out:
# 9000000006
# 0    35000.0
# Name: Income, dtype: float64
# 9123456780
# 1    30000.0
# 2    30000.0
# 3    30000.0
# 4    30000.0
# Name: Income, dtype: float64
# 9123456780
# 1    30000.0
# 2    30000.0
# 3    30000.0
# 4    30000.0
# Name: Income, dtype: float64
# 9123456780
# 1    30000.0
# 2    30000.0
# 3    30000.0
# 4    30000.0
# Name: Income, dtype: float64
# 9123456780
# 1    30000.0
# 2    30000.0
# 3    30000.0
# 4    30000.0
# Name: Income, dtype: float64
# 9123456781
# 5    30000.0
# 6    30000.0
# Name: Income, dtype: float64
# 9123456781
# 5    30000.0
# 6    30000.0
# Name: Income, dtype: float64
# 9123456782
# 7     50000.0
# 8     50000.0
# 9     50000.0
# 10    50000.0
# 11    50000.0
# 12    50000.0
# 13    50000.0
# Name: Income, dtype: float64
# 9123456782
# 7     50000.0
# 8     50000.0
# 9     50000.0
# 10    50000.0
# 11    50000.0
# 12    50000.0
# 13    50000.0
# Name: Income, dtype: float64
# 9123456782
# 7     50000.0
# 8     50000.0
# 9     50000.0
# ...

# %%
p_df[p_df.User_id==9999999987]
# Out:
#         User_id  Category  Bill_Amount    Income    Income_cat
# 117  9999999987         1  1500.000000  30359.09  Lower_Middle
# 118  9999999987         2    57.666667  30359.09  Lower_Middle
# 119  9999999987         6   390.000000  30359.09  Lower_Middle
# 120  9999999987        10  3200.000000  30359.09  Lower_Middle
# 121  9999999987        11  1500.000000  30359.09  Lower_Middle
# 122  9999999987        14   600.000000  30359.09  Lower_Middle

# %%
Unique_list=[]
for user in p_df.User_id:
    if(user not in Unique_list):
        Unique_list.append(user)
        df=p_df[p_df["User_id"]==user]
        print(user)
        label=df["Category"]
        values=df["Bill_Amount"]
        fig1, ax1 = plt.subplots()
        ax1.pie(values,labels=label, autopct='%1.1f%%',
        shadow=True, startangle=90)
        # Equal aspect ratio ensures that pie is drawn as a circle
        ax1.axis('equal')  
        plt.tight_layout()
        plt.show()
# Out:
# 9000000006
# 9123456780
# 9123456781
# 9123456782
# 9123456783
# 9123456784
# 9123456785
# 9123456786
# 9123456787
# 9123456788
# 9123456789
# 9123456790
# 9123456791
# 9123456792
# 9123456793
# 9123456794
# 9123456795
# 9123456796
# 9123456797
# 9123456798
# 9123456799
# 9999999971
# 9999999972
# 9999999973
# 9999999974
# 9999999975
# 9999999976
# 9999999977
# 9999999978
# 9999999979
# 9999999980
# 9999999981
# 9999999982
# 9999999983
# 9999999984
# 9999999985
# 9999999986
# 9999999987
# 9999999988
# 9999999989
# 9999999990
# 9999999991

# %%
p_df["Target"]=""
p_df.head()

# %% [markdown]
#  p_df.head()

# %% [markdown]
# ### Logistic Regression

# %%
p_df.loc[p_df.User_id==9000000006,"Target"]="Luxurious"

# %%
p_df.loc[p_df.User_id==9123456780,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456781,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456782,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456783,"Target"]="Needs"
p_df.loc[p_df.User_id==9123456784,"Target"]="Needs"
p_df.loc[p_df.User_id==9123456785,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456786,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456787,"Target"]="Needs"
p_df.loc[p_df.User_id==9123456788,"Target"]="Needs"
p_df.loc[p_df.User_id==9123456789,"Target"]="Needs"
p_df.loc[p_df.User_id==9123456790,"Target"]="Needs"
p_df.loc[p_df.User_id==9123456791,"Target"]="Needs"
p_df.loc[p_df.User_id==9123456792,"Target"]="Needs"
p_df.loc[p_df.User_id==9123456793,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456794,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456795,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456796,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456797,"Target"]="Needs"

# %%
p_df.loc[p_df.User_id==9123456798,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9123456799,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9999999971,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999972,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999973,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999974,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999975,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999976,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999977,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9999999978,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999979,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9999999980,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9999999981,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9999999982,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999983,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9999999984,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999985,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999986,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999987,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9999999988,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999989,"Target"]="Luxurious"
p_df.loc[p_df.User_id==9999999990,"Target"]="Needs"
p_df.loc[p_df.User_id==9999999991,"Target"]="Luxurious"

# %%
p_df
# Out:
#         User_id  Category   Bill_Amount     Income    Income_cat     Target
# 0    9000000006        11  10000.000000   35000.00  Lower_Middle  Luxurious
# 1    9123456780         8   6500.000000   30000.00  Lower_Middle  Luxurious
# 2    9123456780         9   2150.000000   30000.00  Lower_Middle  Luxurious
# 3    9123456780        10   3000.000000   30000.00  Lower_Middle  Luxurious
# 4    9123456780        11   5875.000000   30000.00  Lower_Middle  Luxurious
# 5    9123456781        10  25000.000000   30000.00  Lower_Middle  Luxurious
# 6    9123456781        11   2500.000000   30000.00  Lower_Middle  Luxurious
# 7    9123456782         1    475.000000   50000.00  Upper_Middle  Luxurious
# 8    9123456782         5    600.000000   50000.00  Upper_Middle  Luxurious
# 9    9123456782         6   1800.000000   50000.00  Upper_Middle  Luxurious
# 10   9123456782         8  22500.000000   50000.00  Upper_Middle  Luxurious
# ...

# %%
p_df.Target.value_counts()
# Out:
# Needs        72
# Luxurious    57
# Name: Target, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
p_df.drop(["Income_cat"],axis=1,inplace=True)

# %%
X=p_df.iloc[:,:-1].values
y=p_df.iloc[:,-1].values
#X
# Out:
# array([[9.00000001e+09, 1.10000000e+01, 1.00000000e+04, 3.50000000e+04],
#        [9.12345678e+09, 8.00000000e+00, 6.50000000e+03, 3.00000000e+04],
#        [9.12345678e+09, 9.00000000e+00, 2.15000000e+03, 3.00000000e+04],
#        [9.12345678e+09, 1.00000000e+01, 3.00000000e+03, 3.00000000e+04],
#        [9.12345678e+09, 1.10000000e+01, 5.87500000e+03, 3.00000000e+04],
#        [9.12345678e+09, 1.00000000e+01, 2.50000000e+04, 3.00000000e+04],
#        [9.12345678e+09, 1.10000000e+01, 2.50000000e+03, 3.00000000e+04],
#        [9.12345678e+09, 1.00000000e+00, 4.75000000e+02, 5.00000000e+04],
#        [9.12345678e+09, 5.00000000e+00, 6.00000000e+02, 5.00000000e+04],
#        [9.12345678e+09, 6.00000000e+00, 1.80000000e+03, 5.00000000e+04],
#        [9.12345678e+09, 8.00000000e+00, 2.25000000e+04, 5.00000000e+04],
#        [9.12345678e+09, 1.00000000e+01, 5.00000000e+03, 5.00000000e+04],
#        [9.12345678e+09, 1.10000000e+01, 1.50000000e+03, 5.00000000e+04],
# ...

# %%
reg=LogisticRegression()
reg.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
p_df[p_df.User_id==9999999987]
# Out:
#         User_id  Category  Bill_Amount    Income     Target
# 117  9999999987         1  1500.000000  30359.09  Luxurious
# 118  9999999987         2    57.666667  30359.09  Luxurious
# 119  9999999987         6   390.000000  30359.09  Luxurious
# 120  9999999987        10  3200.000000  30359.09  Luxurious
# 121  9999999987        11  1500.000000  30359.09  Luxurious
# 122  9999999987        14   600.000000  30359.09  Luxurious

# %%
d={"User_id": pd.Series([9999999992,9999999992,9999999992,9999999992,9999999992,9999999992,9999999992]),
    "Category": pd.Series([1,2,3,5,6,10,11]),
    "Bill_Amount": pd.Series([1500.000000,57.666667,390.000000,3200.0,1500.0,600.0,1500.0]),
    "Income": pd.Series([50000,50000,50000,50000,50000,50000,50000])}
new_df=pd.DataFrame.from_dict(d,orient="index")
new_df=new_df.transpose()
new_df
# Out:
#    Bill_Amount  Category   Income       User_id
# 0  1500.000000       1.0  50000.0  1.000000e+10
# 1    57.666667       2.0  50000.0  1.000000e+10
# 2   390.000000       3.0  50000.0  1.000000e+10
# 3  3200.000000       5.0  50000.0  1.000000e+10
# 4  1500.000000       6.0  50000.0  1.000000e+10
# 5   600.000000      10.0  50000.0  1.000000e+10
# 6  1500.000000      11.0  50000.0  1.000000e+10

# %%
dat={"User_id": pd.Series([9999999995,9999999995,9999999995,9999999995,9999999995]),
    "Category": pd.Series([1,11,10,9,6]),
    "Bill_Amount": pd.Series([15000.00,18000,89000.00,3200.0,3500.0]),
    "Income": pd.Series([65000,65000,65000,65000,65000])}
                         
new_df1=pd.DataFrame.from_dict(dat,orient="index")
new_df1=new_df1.transpose()  
new_df1
# Out:
#    Bill_Amount  Category   Income       User_id
# 0      15000.0       1.0  65000.0  1.000000e+10
# 1      18000.0      11.0  65000.0  1.000000e+10
# 2      89000.0      10.0  65000.0  1.000000e+10
# 3       3200.0       9.0  65000.0  1.000000e+10
# 4       3500.0       6.0  65000.0  1.000000e+10

# %%
reg.predict(new_df)
# Out:
# array(['Needs', 'Needs', 'Needs', 'Needs', 'Needs', 'Needs', 'Needs'],
#       dtype=object)

# %%
reg.predict(new_df1) # Class imbalance problem in data
# Out:
# array(['Needs', 'Needs', 'Needs', 'Needs', 'Needs'], dtype=object)
